# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop('id', axis=1, inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df['diagnosis']=df['diagnosis'].replace({'B':1,'M':0})
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']
print(x.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train, y_test= train_test_split(x,y,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (426, 30)
# (143, 30)
# (426,)
# (143,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
m1=Sequential()
m1.add(Dense(50, activation='relu',input_dim=30))
m1.add(Dense(25, activation='relu'))
m1.add(Dense(12, activation='relu'))
m1.add(Dense(1, activation='sigmoid'))

m1.compile(optimizer='adam',loss='binary_crossentropy', metrics='accuracy')

# %%
h1=m1.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=30)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 2s 23ms/step - loss: 45.2736 - accuracy: 0.3991 - val_loss: 12.8209 - val_accuracy: 0.6294
# Epoch 2/30
# 14/14 [==============================] - 0s 4ms/step - loss: 11.2995 - accuracy: 0.5094 - val_loss: 7.8116 - val_accuracy: 0.3706
# Epoch 3/30
# 14/14 [==============================] - 0s 4ms/step - loss: 2.9015 - accuracy: 0.5587 - val_loss: 1.7786 - val_accuracy: 0.4476
# Epoch 4/30
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8296 - accuracy: 0.6831 - val_loss: 0.3903 - val_accuracy: 0.8392
# Epoch 5/30
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3741 - accuracy: 0.8662 - val_loss: 0.2435 - val_accuracy: 0.9091
# Epoch 6/30
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.9131 - val_loss: 0.2877 - val_accuracy: 0.9021
# Epoch 7/30
# ...

# %%
r1=pd.DataFrame(h1.history)
r1['Epochs']=h1.epoch
r1.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  Epochs
# 25  0.213111  0.917840  0.276791      0.916084      25
# 26  0.309698  0.901408  0.330136      0.902098      26
# 27  0.253973  0.920188  0.282540      0.923077      27
# 28  0.196090  0.927230  0.313698      0.902098      28
# 29  0.216793  0.917840  0.248348      0.916084      29

# %%
plt.plot(r1['Epochs'],r1['loss'],label='Training-data')
plt.plot(r1['Epochs'],r1['val_loss'],label='Test-data')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(r1['Epochs'],r1['accuracy'],label='Training-data')
plt.plot(r1['Epochs'],r1['val_accuracy'],label='Test-data')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
ypred=m1.predict(x_test)
ypred[:10]
# Out:
# 5/5 [==============================] - 0s 1ms/step
# array([[1.1866997e-01],
#        [9.6423143e-01],
#        [9.7534317e-01],
#        [9.3220824e-01],
#        [4.0068243e-02],
#        [9.9453622e-01],
#        [9.9302095e-01],
#        [9.5349032e-01],
#        [9.8019600e-01],
#        [1.6058466e-24]], dtype=float32)
